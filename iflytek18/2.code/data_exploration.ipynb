# %%
import os
#数据处理
import pandas as pd
import numpy as np
import random
import sklearn.preprocessing as preprocessing
#可视化
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data_train_round1 = pd.read_table('../1.data/round1_iflyad_train.txt',sep = '\t')

# %%
data_train_round1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001650 entries, 0 to 1001649
# Data columns (total 35 columns):
# instance_id              1001650 non-null int64
# time                     1001650 non-null int64
# city                     1001650 non-null int64
# province                 1001650 non-null int64
# user_tags                691880 non-null object
# carrier                  1001650 non-null int64
# devtype                  1001650 non-null int64
# make                     902733 non-null object
# model                    994248 non-null object
# nnt                      1001650 non-null int64
# os                       1001650 non-null int64
# osv                      993878 non-null object
# os_name                  1001650 non-null object
# adid                     1001650 non-null int64
# advert_id                1001650 non-null int64
# orderid                  1001650 non-null int64
# advert_industry_inner    1001650 non-null object
# ...

# %%
data_train_round1.head()
# Out:
#            instance_id        time             city         province  \
# 0    86294719979897807  2190219034  137103102105100  137103102100100
# 1  2699289844928136052  2190221070  137105101100100  137105101100100
# 2  3117527168445845752  2190219793  137103104111100  137103104100100
# 3  3398484891050993371  2190221704  137103102113100  137103102100100
# 4  2035477570591176488  2190220024  137103102109100  137103102100100
#
#                                            user_tags  carrier  devtype  \
# 0                                                NaN        1        2
# 1  2100191,2100078,3001825,,3001781,3001791,30017...        3        2
# 2                                                NaN        3        2
# 3  2100098,gd_2100000,3001791,3001795,3002193,300...        0        2
# 4                                                NaN        1        2
#
#      make            model  nnt  ...    creative_width creative_height  \
# ...

# %%
len(set(data_train_round1['model'].get_values()))
# Out:
# 14054

# %%
dir(data_train_round1['click'])
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__idiv__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
# ...

# %%
data_train_round1.describe()
# Out:
#         instance_id          time          city      province       carrier  \
# count  1.001650e+06  1.001650e+06  1.001650e+06  1.001650e+06  1.001650e+06
# mean   4.608551e+18  2.190355e+09  1.346889e+14  1.346889e+14  1.160979e+00
# std    2.661678e+18  1.756326e+05  1.803357e+13  1.803357e+13  6.569081e-01
# min    1.220473e+13  2.190038e+09  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.306312e+18  2.190198e+09  1.371031e+14  1.371031e+14  1.000000e+00
# 50%    4.607022e+18  2.190355e+09  1.371031e+14  1.371031e+14  1.000000e+00
# 75%    6.910921e+18  2.190514e+09  1.371041e+14  1.371041e+14  1.000000e+00
# max    9.223361e+18  2.190643e+09  1.371071e+14  1.371071e+14  3.000000e+00
#
#             devtype           nnt            os          adid     advert_id  \
# count  1.001650e+06  1.001650e+06  1.001650e+06  1.001650e+06  1.001650e+06
# mean   1.999930e+00  1.612798e+00  1.911369e+00  1.554624e+06  2.300005e+08
# ...

# %% [markdown]
# ## 2.1时间
